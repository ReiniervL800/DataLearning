# %%
import pandas as pd

# %%
df=pd.read_csv("Datatevredenheid.csv", sep=";")
df.head()
# Out:
#    ID EigenaarOfHuurder Huishoudkenmerken   Marges   Regio  Perioden  \
# 0   0           T001096           1050010  MW00000  NL01    2002JJ00
# 1   1           T001096           1050010  MW00000  NL01    2006JJ00
# 2   2           T001096           1050010  MW00000  NL01    2009JJ00
# 3   3           T001096           1050010  MW00000  NL01    2012JJ00
# 4   4           T001096           1050010  MW00000  NL01    2015JJ00
#
#    TevredenheidMetDeHuidigeWoning_1  TevredenheidMetDeHuidigeWoonomgeving_2
# 0                              89.2                                    84.3
# 1                              89.7                                    85.0
# 2                              90.0                                    83.4
# 3                              89.0                                    84.1
# 4                              86.9                                    82.0

# %%
df.dropna()
# Out:
#             ID EigenaarOfHuurder Huishoudkenmerken   Marges   Regio  Perioden  \
# 0            0           T001096           1050010  MW00000  NL01    2002JJ00
# 1            1           T001096           1050010  MW00000  NL01    2006JJ00
# 2            2           T001096           1050010  MW00000  NL01    2009JJ00
# 3            3           T001096           1050010  MW00000  NL01    2012JJ00
# 4            4           T001096           1050010  MW00000  NL01    2015JJ00
# ...        ...               ...               ...      ...     ...       ...
# 205873  205873           A025406           A025782  MBG0095  GM0599  2006JJ00
# 205874  205874           A025406           A025782  MBG0095  GM0599  2009JJ00
# 205875  205875           A025406           A025782  MBG0095  GM0599  2012JJ00
# 205886  205886           A025406           A025782  MBG0095  GM0344  2009JJ00
# 205890  205890           A025406           A025782  MBG0095  GM0983  2002JJ00
#
# ...

# %%
df.describe()
# Out:
#                   ID  TevredenheidMetDeHuidigeWoning_1  \
# count  205920.000000                     130596.000000
# mean   102959.500000                         83.250744
# std     59444.128053                         12.781505
# min         0.000000                          0.000000
# 25%     51479.750000                         76.300000
# 50%    102959.500000                         85.700000
# 75%    154439.250000                         93.000000
# max    205919.000000                        100.000000
#
#        TevredenheidMetDeHuidigeWoonomgeving_2
# count                           130596.000000
# mean                                80.270772
# std                                 10.434411
# min                                  0.000000
# 25%                                 74.300000
# 50%                                 81.900000
# 75%                                 88.000000
# max                                100.000000

# %%
df_35=df[df["Huishoudkenmerken"]==A025395]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-94cf0f5b657a> in <module>
# ----> 1 df_35=df[df["Huishoudkenmerken"]==A025395]
#
# NameError: name 'A025395' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize = (15,8))
plt.xticks(rotation=45)
sns.violinplot(x='Huishoudkenmerken',y='TevredenheidMetDeHuidigeWoning_1',data=df)
plt.title('Tevredenheid woning')
plt.xlabel('Huishoud kenmerken')
plt.ylabel('Tevredenheid')
plt.show()

# %%
plt.figure(figsize = (15,8))
plt.xticks(rotation=45)
sns.violinplot(x='Huishoudkenmerken',y='TevredenheidMetDeHuidigeWoonomgeving_2',data=df)
plt.title('Tevredenheid woonomgeving')
plt.xlabel('Huishoud kenmerken')
plt.ylabel('Tevredenheid')
plt.show()

# %%
sns.violinplot(x='EigenaarOfHuurder',y='TevredenheidMetDeHuidigeWoning_1',data=df)
plt.title('Tevredenheid woning')
plt.xlabel("EigenaarofHuurder")
plt.ylabel('Tevredenheid')
plt.show()

# %%
sns.violinplot(x='EigenaarOfHuurder',y='TevredenheidMetDeHuidigeWoonomgeving_2',data=df)
plt.title('Tevredenheid woonomgeving')
plt.xlabel("EigenaarofHuurder")
plt.ylabel('Tevredenheid')
plt.show()
